# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import numpy as np

# %%
import altair as alt

# %%
df = pd.read_csv("crypto_compare.csv", index_col=0)

# %%
df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Cryptocurrencies on trading
df = df[df['IsTrading']==True]
df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Cryptocurrencies with a working algorithm
df_algor = df[df['Algorithm'] != "N/A"]
df_algor.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Removing the "Istrading" column
df_crypto = df_algor.drop(columns="IsTrading")
df_crypto.head()
# Out:
#       CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       PoW              NaN          611000
# 808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Removing rows with missing data
df_crypto.dropna(inplace = True)

# %%
# Checking isnull
for column in df_crypto.columns:
    print(f"Column {column} has {df_crypto[column].isnull().sum()} null values")
# Out:
# Column CoinName has 0 null values
# Column Algorithm has 0 null values
# Column ProofType has 0 null values
# Column TotalCoinsMined has 0 null values
# Column TotalCoinSupply has 0 null values

# %%
# Removing rows with cryptocurrencies without coins mined
df_crypto = df_crypto[df_crypto['TotalCoinsMined'] != 0]
df_crypto.head()
# Out:
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Dropping rows where there are 'N/A' text values

# %%
df_crypto.dropna()
df_crypto.tail()
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000

# %%
# Fetching the cryptocurrencies names

# %%
X = df_crypto["CoinName"]

# %%
df_X = df_crypto[["CoinName"]]
df_X.head()
# Out:
#        CoinName
# 42      42 Coin
# 404     404Coin
# 1337  EliteCoin
# BTC     Bitcoin
# ETH    Ethereum

# %%
# Removing the cryptocurrencies names
df_crypto_clean = df_crypto.drop(columns="CoinName")
df_crypto_clean.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
# Creating dummies variables for text features

# %%
df_dummies = pd.get_dummies(df_crypto_clean)

# %%
df_dummies.head()
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 42       4.199995e+01                                 0              0
# 404      1.055185e+09                                 0              0
# 1337     2.927942e+10                                 0              0
# BTC      1.792718e+07                                 0              0
# ETH      1.076842e+08                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                    0                   0                0
# 404                   0                   0                0
# 1337                  0                   0                0
# BTC                   0                   0                0
# ETH                   0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  \
# 42                    0                  0              0
# 404                   0                  0              0
# 1337                  0                  0              0
# BTC                   0                  0              0
# ETH                   0                  0              0
#
#       Algorithm_Cloverhash  ...  TotalCoinSupply_91388946  \
# 42                       0  ...                         0
# 404                      0  ...                         0
# 1337                     0  ...                         0
# BTC                      0  ...                         0
# ETH                      0  ...                         0
#
#       TotalCoinSupply_92000000000  TotalCoinSupply_9354000  \
# 42                              0                        0
# 404                             0                        0
# 1337                            0                        0
# BTC                             0                        0
# ETH                             0                        0
#
#       TotalCoinSupply_9507271  TotalCoinSupply_9736000  \
# 42                          0                        0
# 404                         0                        0
# 1337                        0                        0
# BTC                         0                        0
# ETH                         0                        0
#
#       TotalCoinSupply_98000000  TotalCoinSupply_98100000000  \
# 42                           0                            0
# 404                          0                            0
# 1337                         0                            0
# BTC                          0                            0
# ETH                          0                            0
#
#       TotalCoinSupply_990000000000  TotalCoinSupply_999481516  \
# 42                               0                          0
# 404                              0                          0
# 1337                             0                          0
# BTC                              0                          0
# ETH                              0                          0
#
#       TotalCoinSupply_9999999
# 42                          0
# 404                         0
# 1337                        0
# BTC                         0
# ETH                         0
#
# [5 rows x 379 columns]

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533 entries, 42 to XBC
# Columns: 379 entries, TotalCoinsMined to TotalCoinSupply_9999999
# dtypes: float64(1), uint8(378)
# memory usage: 225.1+ KB

# %%
# Standardizing data cScore
df_standar = StandardScaler().fit_transform(df_dummies)
print(df_standar[0:5])
# Out:
# [[-0.11674788 -0.0433555  -0.0433555  ... -0.0433555  -0.0433555
#   -0.0433555 ]
#  [-0.09358885 -0.0433555  -0.0433555  ... -0.0433555  -0.0433555
#   -0.0433555 ]
#  [ 0.52587231 -0.0433555  -0.0433555  ... -0.0433555  -0.0433555
#   -0.0433555 ]
#  [-0.11635442 -0.0433555  -0.0433555  ... -0.0433555  -0.0433555
#   -0.0433555 ]
#  [-0.11438445 -0.0433555  -0.0433555  ... -0.0433555  -0.0433555
#   -0.0433555 ]]

# %%
# Reducing Dimensions Using PCA

# %%
# Applying PCA to reduce dimensions to 3 principal components

# Initialize PCA model
pca = PCA(n_components=3)

# Get three principal components for the df_standar.
redu_pca = pca.fit_transform(df_standar)

redu_pca
# Out:
# array([[-0.20937467, -0.05501095, -0.01782618],
#        [-0.20128244, -0.05724332, -0.01326209],
#        [ 0.27587699, -0.02240677, -0.2213532 ],
#        ...,
#        [ 0.10803011, -0.0849067 , -0.14208644],
#        [-0.15333101, -0.1362789 , -0.03429066],
#        [-0.27496615, -0.03671852, -0.0849353 ]])

# %%
# Creating a DataFrame with the principal components data

# %%
# Transform PCA data to a DataFrame
df_pca = pd.DataFrame(
    data=redu_pca, columns=["principal component 1", "principal component 2", "principal component 3"])

df_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0              -0.209375              -0.055011              -0.017826
# 1              -0.201282              -0.057243              -0.013262
# 2               0.275877              -0.022407              -0.221353
# 3              -0.147245              -0.142379              -0.040856
# 4              -0.105411              -0.145567              -0.176638

# %%
# Clustering Cryptocurrencies Using K-Means
# Finding the Best Value for k Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range ok k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_pca)
    inertia.append(km.inertia_)


# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
# df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")

# %%
df_elbow.head()
# Out:
#    k      inertia
# 0  1  4877.368639
# 1  2  3305.543523
# 2  3  1965.575756
# 3  4   704.051563
# 4  5   278.521163

# %%
chart = alt.Chart(df_elbow).mark_line().encode(
    x='k',
    y='inertia',
    )
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# Running K-Means with k=<you best value for k here

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=5, random_state=0)

# Fit the model
model.fit(df_pca)

# Predict clusters
predictions = model.predict(df_pca)

# Creating a new DataFrame including predicted clusters and cryptocurrencies features
df_pca["class"] = model.labels_
df_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  class
# 0              -0.209375              -0.055011              -0.017826      0
# 1              -0.201282              -0.057243              -0.013262      0
# 2               0.275877              -0.022407              -0.221353      0
# 3              -0.147245              -0.142379              -0.040856      0
# 4              -0.105411              -0.145567              -0.176638      0

# %%
# Creating a new DataFrame

# %%
df_crypto.head()
# Out:
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0

# %%
df_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  class
# 0              -0.209375              -0.055011              -0.017826      0
# 1              -0.201282              -0.057243              -0.013262      0
# 2               0.275877              -0.022407              -0.221353      0
# 3              -0.147245              -0.142379              -0.040856      0
# 4              -0.105411              -0.145567              -0.176638      0

# %%
df_pca["symbol"] = df_X.index
df_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  class  \
# 0              -0.209375              -0.055011              -0.017826      0
# 1              -0.201282              -0.057243              -0.013262      0
# 2               0.275877              -0.022407              -0.221353      0
# 3              -0.147245              -0.142379              -0.040856      0
# 4              -0.105411              -0.145567              -0.176638      0
#
#   symbol
# 0     42
# 1    404
# 2   1337
# 3    BTC
# 4    ETH

# %%
df_crypto_clean.reset_index(inplace=True)
df_crypto_clean.head()
# Out:
#   index Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    42    Scrypt   PoW/PoS     4.199995e+01              42
# 1   404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 2  1337       X13   PoW/PoS     2.927942e+10    314159265359
# 3   BTC   SHA-256       PoW     1.792718e+07        21000000
# 4   ETH    Ethash       PoW     1.076842e+08               0

# %%
df_cd = pd.merge(df_crypto_clean, df_pca, how='inner', left_on = 'index', right_on = 'symbol', left_index=False)
df_cd.head()
# Out:
#   index Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# 0    42    Scrypt   PoW/PoS     4.199995e+01              42
# 1   404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 2  1337       X13   PoW/PoS     2.927942e+10    314159265359
# 3   BTC   SHA-256       PoW     1.792718e+07        21000000
# 4   ETH    Ethash       PoW     1.076842e+08               0
#
#    principal component 1  principal component 2  principal component 3  class  \
# 0              -0.209375              -0.055011              -0.017826      0
# 1              -0.201282              -0.057243              -0.013262      0
# 2               0.275877              -0.022407              -0.221353      0
# 3              -0.147245              -0.142379              -0.040856      0
# 4              -0.105411              -0.145567              -0.176638      0
#
#   symbol
# 0     42
# 1    404
# 2   1337
# 3    BTC
# 4    ETH

# %%
df_cd.set_index('index',inplace=True)
df_cd.head()
# Out:
#       Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# index
# 42       Scrypt   PoW/PoS     4.199995e+01              42
# 404      Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337        X13   PoW/PoS     2.927942e+10    314159265359
# BTC     SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethash       PoW     1.076842e+08               0
#
#        principal component 1  principal component 2  principal component 3  \
# index
# 42                 -0.209375              -0.055011              -0.017826
# 404                -0.201282              -0.057243              -0.013262
# 1337                0.275877              -0.022407              -0.221353
# BTC                -0.147245              -0.142379              -0.040856
# ETH                -0.105411              -0.145567              -0.176638
#
#        class symbol
# index
# 42         0     42
# 404        0    404
# 1337       0   1337
# BTC        0    BTC
# ETH        0    ETH

# %%
clustered_df= df_cd[['Algorithm','ProofType','TotalCoinsMined','TotalCoinSupply','principal component 1','principal component 2','principal component 3','symbol','class']]
clustered_df.head()
# Out:
#       Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# index
# 42       Scrypt   PoW/PoS     4.199995e+01              42
# 404      Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337        X13   PoW/PoS     2.927942e+10    314159265359
# BTC     SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethash       PoW     1.076842e+08               0
#
#        principal component 1  principal component 2  principal component 3  \
# index
# 42                 -0.209375              -0.055011              -0.017826
# 404                -0.201282              -0.057243              -0.013262
# 1337                0.275877              -0.022407              -0.221353
# BTC                -0.147245              -0.142379              -0.040856
# ETH                -0.105411              -0.145567              -0.176638
#
#       symbol  class
# index
# 42        42      0
# 404      404      0
# 1337    1337      0
# BTC      BTC      0
# ETH      ETH      0

# %%
# Adding CoinName column to clustered_df and changing the name to df

# %%
clustered_df.reset_index(inplace=True)
df_X.reset_index(inplace=True)

# %%
df=pd.merge(clustered_df, df_X, on='index')
df.head()
# Out:
#   index Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# 0    42    Scrypt   PoW/PoS     4.199995e+01              42
# 1   404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 2  1337       X13   PoW/PoS     2.927942e+10    314159265359
# 3   BTC   SHA-256       PoW     1.792718e+07        21000000
# 4   ETH    Ethash       PoW     1.076842e+08               0
#
#    principal component 1  principal component 2  principal component 3 symbol  \
# 0              -0.209375              -0.055011              -0.017826     42
# 1              -0.201282              -0.057243              -0.013262    404
# 2               0.275877              -0.022407              -0.221353   1337
# 3              -0.147245              -0.142379              -0.040856    BTC
# 4              -0.105411              -0.145567              -0.176638    ETH
#
#    class   CoinName
# 0      0    42 Coin
# 1      0    404Coin
# 2      0  EliteCoin
# 3      0    Bitcoin
# 4      0   Ethereum

# %%
### Visualizing Results

# %%
cluster_chart=alt.Chart(df).mark_circle(size=60).encode(
    x='principal component 1',
    y='principal component 2',
    tooltip=['principal component 3']).interactive()
cluster_chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
fig = px.scatter_3d(
    clustered_df,
    x='principal component 1',
    y='principal component 2',
    z='principal component 3',
    color='class',
    symbol='class',
    hover_name="symbol",
    hover_data=["Algorithm"],
    width=800
)
# Use py.iplot() for IPython notebook
#py.iplot(fig, filename='3d point clustering')
fig.show()
# Out:
# <div>
#
#
#             <div id="f24888e8-b042-4704-be42-c61df6ab34e6" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f24888e8-b042-4704-be42-c61df6ab34e6")) {
#                     Plotly.newPlot(
#                         'f24888e8-b042-4704-be42-c61df6ab34e6',
#                         [{"customdata": [["Scrypt"], ["Scrypt"], ["X13"], ["SHA-256"], ["Ethash"], ["Scrypt"], ["X11"], ["CryptoNight-V7"], ["Ethash"], ["Equihash"], ["SHA-512"], ["Multiple"], ["SHA-256"], ["SHA-256"], ["Scrypt"], ["X15"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Multiple"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Quark"], ["Groestl"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X11"], ["Scrypt"], ["Groestl"], ["Multiple"], ["SHA-256"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["PoS"], ["Scrypt"], ["Scrypt"], ["NeoScrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X11"], ["Scrypt"], ["X11"], ["SHA-256"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA3"], ["Scrypt"], ["HybridScryptHash256"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["X13"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["X13"], ["NeoScrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X11"], ["X11"], ["SHA-256"], ["Multiple"], ["SHA-256"], ["PHI1612"], ["X11"], ["SHA-256"], ["SHA-256"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Lyra2REv2"], ["Scrypt"], ["X11"], ["Multiple"], ["SHA-256"], ["X13"], ["Scrypt"], ["CryptoNight"], ["CryptoNight"], ["Shabal256"], ["Counterparty"], ["Scrypt"], ["SHA-256"], ["Groestl"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["Scrypt"], ["Stanford Folding"], ["X11"], ["Multiple"], ["QuBit"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["M7 POW"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["X11"], ["SHA3"], ["X11"], ["Lyra2RE"], ["SHA-256"], ["QUAIT"], ["X11"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Ethash"], ["X13"], ["Blake2b"], ["SHA-256"], ["X15"], ["X11"], ["SHA-256"], ["BLAKE256"], ["Scrypt"], ["1GB AES Pattern Search"], ["SHA-256"], ["X11"], ["Scrypt"], ["SHA-256"], ["SHA-256"], ["NIST5"], ["Scrypt"], ["Scrypt"], ["X11"], ["Dagger"], ["Scrypt"], ["X11GOST"], ["X11"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["PoS"], ["Scrypt"], ["X11"], ["X11"], ["SHA-256"], ["SHA-256"], ["NIST5"], ["X11"], ["Scrypt"], ["POS 3.0"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["X11"], ["X11"], ["Equihash"], ["X11"], ["Scrypt"], ["CryptoNight"], ["SHA-256"], ["SHA-256"], ["X11"], ["Scrypt"], ["Multiple"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["Scrypt"], ["SHA-256D"], ["PoS"], ["Scrypt"], ["X11"], ["Lyra2Z"], ["PoS"], ["X13"], ["X14"], ["PoS"], ["SHA-256D"], ["Ethash"], ["Equihash"], ["DPoS"], ["X11"], ["Scrypt"], ["X11"], ["X13"], ["X11"], ["PoS"], ["Scrypt"], ["Scrypt"], ["X11"], ["PoS"], ["X11"], ["SHA-256"], ["Scrypt"], ["X11"], ["Scrypt"], ["Scrypt"], ["X11"], ["CryptoNight"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Quark"], ["QuBit"], ["Scrypt"], ["CryptoNight"], ["Lyra2RE"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["X11"], ["Scrypt"], ["CryptoNight-V7"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["X11"], ["Equihash"], ["Scrypt"], ["Scrypt"], ["Lyra2RE"], ["Scrypt"], ["Dagger-Hashimoto"], ["X11"], ["Blake2S"], ["X11"], ["Scrypt"], ["PoS"], ["X11"], ["NIST5"], ["PoS"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["PoS"], ["Scrypt"], ["X15"], ["SHA-256"], ["Scrypt"], ["POS 3.0"], ["CryptoNight-V7"], ["536"], ["Argon2d"], ["Blake2b"], ["Cloverhash"], ["CryptoNight"], ["NIST5"], ["X11"], ["NIST5"], ["Skein"], ["Scrypt"], ["X13"], ["Scrypt"], ["X11"], ["X11"], ["Scrypt"], ["CryptoNight"], ["X13"], ["Time Travel"], ["Scrypt"], ["Keccak"], ["SkunkHash v2 Raptor"], ["X11"], ["Skein"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["PoS"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["CryptoNight"], ["SHA-512"], ["Ouroboros"], ["X11"], ["Equihash"], ["NeoScrypt"], ["X11"], ["Scrypt"], ["NeoScrypt"], ["Lyra2REv2"], ["Equihash"], ["Scrypt"], ["SHA-256"], ["NIST5"], ["PHI1612"], ["Dagger"], ["Scrypt"], ["Quark"], ["Scrypt"], ["PO ...

# %%
df = df.astype({"TotalCoinSupply":'float64'})
trade_chart=alt.Chart(df).mark_circle(size=60).encode(
    x='TotalCoinsMined',
    y='TotalCoinSupply',
    tooltip=['CoinName']).interactive()
trade_chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# Altair scatter plot to visualize the tradable currencies Total Coins Mined and Total Coin Supply

# %%
df_table = df[["CoinName", "Algorithm", "ProofType", "TotalCoinsMined", "TotalCoinSupply", "class"]]
display(df_table.head(10))
# Out:
#            CoinName       Algorithm ProofType  TotalCoinsMined  \
# 0           42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 1           404Coin          Scrypt   PoW/PoS     1.055185e+09
# 2         EliteCoin             X13   PoW/PoS     2.927942e+10
# 3           Bitcoin         SHA-256       PoW     1.792718e+07
# 4          Ethereum          Ethash       PoW     1.076842e+08
# 5          Litecoin          Scrypt       PoW     6.303924e+07
# 6              Dash             X11   PoW/PoS     9.031294e+06
# 7            Monero  CryptoNight-V7       PoW     1.720114e+07
# 8  Ethereum Classic          Ethash       PoW     1.133597e+08
# 9             ZCash        Equihash       PoW     7.383056e+06
#
#    TotalCoinSupply  class
# 0     4.200000e+01      0
# 1     5.320000e+08      0
# 2     3.141593e+11      0
# 3     2.100000e+07      0
# 4     0.000000e+00      0
# 5     8.400000e+07      0
# 6     2.200000e+07      0
# 7     0.000000e+00      0
# 8     2.100000e+08      0
# 9     2.100000e+07      0

# %%
# df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', hover_cols=["CoinName"])

# %%
fig = px.scatter_3d(
    df,
    x='principal component 1',
    y='principal component 2',
    z='principal component 3'
    
)
fig.show()
# Out:
# <div>
#
#
#             <div id="f5387b3b-6fea-4333-a7e7-d7575738f1ef" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5387b3b-6fea-4333-a7e7-d7575738f1ef")) {
#                     Plotly.newPlot(
#                         'f5387b3b-6fea-4333-a7e7-d7575738f1ef',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "principal component 1=%{x}<br>principal component 2=%{y}<br>principal component 3=%{z}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": [-0.3074398781759123, -0.2881707073907965, 0.3029956753196095, -0.1757869276489, -0.11579296869913944, -0.25878970655234507, -0.24032040346549877, -0.08368878953462884, -0.2810882894881882, -0.2323169542104814, -0.5069598995229347, 0.008209006468285712, -0.17641054869801315, -0.1392309838470491, -0.2596163752484857, -0.21903457044779936, -0.27019199390264753, -0.26974783715808137, -0.3007817465876278, -0.11772635661274741, 0.08932582583788938, -0.2889836128423103, -0.136739449424545, -0.29193556667103093, -0.1943437142377523, -0.12338228567354224, -0.2149408693193196, -0.22564434599390554, -0.2927556119609389, -0.30488816550450276, -0.29129757670690287, -0.3096595280779568, -0.29925265723888933, -0.2674825773010907, 0.677885093843704, -0.25302323926081544, 0.07221216493628678, 0.100438215698558, -0.09006472890777621, -0.2911464477037199, -0.2884178229531818, -0.29224466437403007, -0.14242632835101374, -0.0539913460260501, -0.28864563094139556, -0.1697999818390198, -0.27364555591740164, -0.2774175573749577, -0.2903733979062212, -0.2909241235027879, -0.07729585289364906, 1.1674599448619056, -0.24022525190717484, -0.17575202056509975, -0.2911858058188896, -0.2898016363656203, -0.29484055090214617, -0.12018489989013637, -0.26739876031339715, -0.25786073664730247, 0.11953774212536644, -0.26343021672562905, -0.1273287536356871, -0.3026140479112201, -0.03923711810357646, -0.2538031730828551, -0.17582215045775618, -0.2861917603486955, -0.03979933995676876, -0.19333969535748438, -0.29247332143445975, -0.3036663404